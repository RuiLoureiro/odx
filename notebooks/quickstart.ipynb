# %%
# %run ~/tese/repo/notebooks/boilerplate.ipynb
# Out:
# <style>
#     div#notebook-container    { width: 95%; }
#     div#menubar-container     { width: 65%; }
#     div#maintoolbar-container { width: 99%; }
# </style>

# %%
from odx.bus_schedule import BusSchedule
from odx.metro_schedule import MetroSchedule

# %%
bus_sched = BusSchedule()
# Out:
# 2021-02-06 21:31:59.470 | INFO     | odx.bus_schedule:__init__:215 - Initializing Schedule object. Loading routes in /Users/ruiloureiro/tese/repo/data/processed/routes.json and stops in /Users/ruiloureiro/tese/repo/data/processed/stops.json..

# %%
bus_sched
# Out:
# Bus Schedule with 316 routes and 2193 stops

# %%
bus_sched.stops
# Out:
# [<101> [Esc. Rainha D. Leonor] (38.751834, -9.143217),
#  <102> [Esc. Rainha D. Leonor] (38.752082, -9.143613),
#  <103> [Pç. Alvalade (Esc. Eugénio Santos)] (38.754216, -9.144418),
#  <104> [Pç. Alvalade (Esc. Eugénio Santos)] (38.754048, -9.144636),
#  <105> [Pç. Alvalade] (38.753475, -9.142573),
#  <106> [Pç. Alvalade (Esc. Eugénio Santos)] (38.754736, -9.144655),
#  <108> [Pç. Alvalade] (38.753415, -9.143272),
#  <201> [B.º S. Miguel - Av. Roma] (38.747568, -9.140826),
#  <202> [B.º S. Miguel - Av. Roma] (38.747428, -9.141082),
#  <203> [Av. Roma / Av. EUA] (38.750084, -9.142147),
#  <204> [Av. Roma / Av. EUA] (38.750001, -9.142509),
#  <205> [Av. Roma / Av. EUA] (38.749342, -9.142792),
#  <208> [Av. Roma / Av. EUA] (38.749, -9.142617),
#  <301> [Areeiro - Av. Afonso Costa] (38.742288, -9.131901),
#  <302> [Areeiro] (38.742139, -9.13445),
#  <304> [Av. João XXI / Pç. Londres] (38.742367, -9.137565),
#  <305> [Av. João XXI / Pç. Londres] (38.74251, -9.136339),
# ...

# %%
bus_sched.routes
# Out:
# [201 ASC [0] (3807->94904),
#  201 DESC [0] (94903->3807),
#  202 ASC [0] (3811->14107),
#  202 DESC [0] (14107->3811),
#  202 DESC [1] (13911->3811),
#  206 ASC [0] (3801->15101),
#  206 ASC [1] (3801->11501),
#  206 DESC [0] (15101->3801),
#  207 ASC [0] (3812->16001),
#  207 DESC [0] (16001->3812),
#  208 ASC [0] (3810->7817),
#  208 DESC [0] (7817->3810),
#  210 ASC [0] (3804->16310),
#  210 DESC [0] (16310->3804),
#  701 ASC [0] (5829->8016),
#  701 ASC [3] (5829->1622),
#  701 DESC [0] (8016->5829),
#  701 DESC [3] (1622->5829),
#  702 ASC [0] (1221->2722),
#  702 ASC [1] (1221->2709),
#  702 ASC [3] (2701->2722),
#  702 DESC [0] (2722->1221),
#  702 DESC [1] (2709->1221),
#  702 DESC [3] (2722->2704),
#  703 ASC [0] (6007->2905),
#  703 ASC [1] (6007->10803),
#  703 DESC [0] (2905->6007),
#  703 DESC [1] (10807->6007),
#  705 ASC [0] (7816->320),
#  705 DESC [0] (320->7816),
#  706 ASC [0] (3804->2133),
#  706 ASC [1] (504->2133),
#  706 ASC [3] (4509->2133),
# ...

# %%
metro_sched = MetroSchedule()

# %%
metro_sched.stops
# Out:
# [<49> [AEROPORTO] (38.76862, -9.12833),
#  <23> [ALAMEDA] (38.73696, -9.13389),
#  <43> [ALFORNELOS] (38.76035, -9.20455),
#  <4> [ALTO DOS MOINHOS] (38.74993, -9.18007),
#  <20> [ALVALADE] (38.75327, -9.1441),
#  <44> [AMADORA ESTE] (38.75855, -9.21794),
#  <40> [AMEIXOEIRA] (38.77953, -9.15961),
#  <25> [ANJOS] (38.72703, -9.13488),
#  <22> [AREEIRO] (38.74228, -9.13349),
#  <11> [AVENIDA] (38.71934, -9.14513),
#  <29> [BAIXA-CHIADO] (38.71041, -9.14018),
#  <32> [BELA VISTA] (38.7476, -9.11772),
#  <35> [CABO RUIVO] (38.76294, -9.10518),
#  <30> [CAIS DO SODRE] (38.70611, -9.14612),
#  <13> [CAMPO GRANDE] (38.76016, -9.15788),
#  <16> [CAMPO PEQUENO] (38.74079, -9.14673),
#  <2> [CARNIDE] (38.75901, -9.19276),
#  <33> [CHELAS] (38.75475, -9.11404),
#  <14> [CIDADE UNIVERSITÁRIA] (38.75144, -9.15915),
#  <3> [COLÉGIO MILITAR-LUZ] (38.75372, -9.18987),
#  <48> [ENCARNAÇÃO] (38.77499, -9.11538),
#  <15> [ENTRECAMPOS] (38.74698, -9.14823),
#  <26> [INTENDENTE] (38.72326, -9.13526),
# ...

# %%
metro_sched.routes
# Out:
# [[Metro Route 'AMARELA'] (RATO<->ODIVELAS),
#  [Metro Route 'AZUL'] (REBOLEIRA<->SANTA APOLÓNIA),
#  [Metro Route 'VERMELHA'] (AEROPORTO<->SÃO SEBASTIÃO),
#  [Metro Route 'VERDE'] (CAIS DO SODRE<->TELHEIRAS)]
